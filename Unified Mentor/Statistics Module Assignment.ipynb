# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame

data = pd.read_csv('Telecom Dataset.csv')

# %%
# Take a brief look at the data
data.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (50, 17)

# %%
# Get the column names of the dataframe
data.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Look at basic information about the dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe
data.columns
data[['Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem']]
blue_condition = data['Blue'] == True
wifi_condition = data['Wi_Fi'] == True
tch_scr_condition = data['Tch_Scr'] == True
ext_mem_condition = data['Ext_Mem'] == True

print("Logical condition for Blue:")
print(blue_condition)

print("\nLogical condition for Wi_Fi:")
print(wifi_condition)

print("\nLogical condition for Tch_Scr:")
print(tch_scr_condition)

print("\nLogical condition for Ext_Mem:")
print(ext_mem_condition)
# Out:
# Logical condition for Blue:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Blue, dtype: bool
#
# Logical condition for Wi_Fi:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Wi_Fi, dtype: bool
#
# Logical condition for Tch_Scr:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Tch_Scr, dtype: bool
#
# Logical condition for Ext_Mem:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Ext_Mem, dtype: bool

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"

con1 = (data['Blue'] == True) & (data['Wi_Fi'] == True) & (data['Tch_Scr'] == True) & (data['Ext_Mem'] == True)
con1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe

data[['Px_h','Px_w']]
# Out:
#     Px_h  Px_w
# 0    780   460
# 1    780   560
# 2    840   720
# 3   1280  1120
# 4   1280  1080
# 5   1280  1080
# 6   1390  1080
# 7   2880  2120
# 8   2580  1920
# 9   2580  1980
# 10  2580  1920
# 11  2580  1920
# 12  2580  1980
# 13  2880  2120
# 14  2380  1820
# 15  1980  1760
# 16  2580  1980
# 17  2880  2120
# 18  1980  1760
# 19  2880  2120
# 20  1980  1760
# 21  2580  1980
# 22  1440  1280
# 23  2880  2120
# 24  1440  1280
# 25  2580  1980
# 26  1980  1280
# 27  2580  2120
# 28  2580  2120
# 29  2580  2120
# 30  2580  2120
# 31  2580  2120
# 32  2580  2120
# 33  2580  2120
# 34  2880  2120
# 35  2440  2120
# 36  2580  1980
# 37  2440  1980
# 38  2580  1920
# 39  2440  1980
# 40  2580  1980
# 41  2580  1980
# 42  2580  1980
# 43  2580  1980
# 44  2580  1980
# 45  2580  1980
# 46  2580  1980
# 47  2880  2520
# 48  2880  2520
# 49  2880  2520

# %%
# Let's tackle these features: "Px_h", "Px_w"

# %%
# Create a new feature called "Px" which stores the total resolution of the screen
data['Px'] =  data['Px_h'] * data['Px_w']

# %%
# Create a histogram of the "Px" feature and also show the mean and the median

sns.histplot(data['Px'],color ='g')
plt.vlines(data['Px'].mean(),ymin=0,ymax=49)
plt.vlines(data['Px'].median(),ymin=0,ymax=49)

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"

median_resolution = data['Px'].median()

# Create the logical condition where the resolution is greater than or equal to the median
con2 = data['Px'] >= median_resolution

# Print the logical values
print(con2)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: Px, dtype: bool

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"

data[[ "Scr_h", "Scr_w"]]
# Out:
#     Scr_h  Scr_w
# 0       3      1
# 1       2      1
# 2       2      1
# 3       5      3
# 4       4      3
# 5       4      3
# 6       6      3
# 7       8      6
# 8       6      3
# 9       5      3
# 10      6      3
# 11      8      6
# 12      6      5
# 13      6      5
# 14      5      3
# 15     10      8
# 16      8      6
# 17      8      6
# 18      8      6
# 19      4      3
# 20      4      3
# 21      8      6
# 22      4      3
# 23     10      8
# 24      6      4
# 25      6      3
# 26      5      3
# 27      8      6
# 28      8      6
# 29      8      6
# 30      8      6
# 31      8      6
# 32      8      6
# 33      8      6
# 34      6      3
# 35      5      3
# 36     10      8
# 37      5      3
# 38      5      3
# 39      6      5
# 40      5      3
# 41      8      6
# 42      8      6
# 43      8      6
# 44     10      8
# 45      8      6
# 46      4      3
# 47      8      6
# 48      8      6
# 49      8      6

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone

data['Scr_d'] = np.sqrt(data['Scr_h']**2 + data['Scr_w']**2)

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles

# Plot histogram of the Scr_d feature
plt.figure(figsize=(8, 6))
plt.hist(data['Scr_d'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Screen Diagonal Length (Scr_d)', fontsize=14)
plt.xlabel('Diagonal Length (Scr_d)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show quartiles
q1 = data['Scr_d'].quantile(0.25)
q2 = data['Scr_d'].quantile(0.50)
q3 = data['Scr_d'].quantile(0.75)

plt.axvline(q1, color='r', linestyle='dashed', linewidth=2, label=f'25th percentile: {q1:.2f}')
plt.axvline(q2, color='g', linestyle='dashed', linewidth=2, label=f'50th percentile (Median): {q2:.2f}')
plt.axvline(q3, color='b', linestyle='dashed', linewidth=2, label=f'75th percentile: {q3:.2f}')
plt.legend()
plt.show()

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"


upper_quartile = data['Scr_d'].quantile(0.75)
con3 = data['Scr_d'] >= upper_quartile
print(con3)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49     True
# Name: Scr_d, dtype: bool

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"

# %%
# Create a histogram of the "PC" feature and also show the mean and the median

# Calculate the 50th percentile (Median)
median_scr_d = data['Scr_d'].median()

# Create a logical condition for phones with screen sizes greater than or equal to the median
con3_median = data['Scr_d'] >= median_scr_d

# Display the condition
print(con3_median)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39     True
# 40    False
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49     True
# Name: Scr_d, dtype: bool

# %%
# Create a histogram of the "FC" feature and also show the mean and the median

# Create the histogram
plt.figure(figsize=(8,6))
plt.hist(data['FC'], bins=10, edgecolor='black', color='skyblue', alpha=0.7)

# Calculate the mean and median
mean_fc = data['FC'].mean()
median_fc = data['FC'].median()

# Add lines for mean and median
plt.axvline(mean_fc, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_fc:.2f}')
plt.axvline(median_fc, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_fc:.2f}')

# Labels and title
plt.xlabel('Front Camera Megapixels (FC)')
plt.ylabel('Frequency')
plt.title('Histogram of Front Camera Megapixels (FC)')
plt.legend()

# Show the plot
plt.show()

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"
# Calculate the mean values for primary and front camera resolutions
mean_pc = data['PC'].mean()
mean_fc = data['FC'].mean()

# Create logical condition for phones with good primary and front camera resolutions
con4 = (data['PC'] >= mean_pc) & (data['FC'] >= mean_fc)

# Show the logical condition as a new column
data['con4'] = con4

# Display the dataframe to verify the new column
print(data[['PC', 'FC', 'con4']])
# Out:
#      PC  FC   con4
# 0     2   2  False
# 1     4   2  False
# 2     4   2  False
# 3     6   2  False
# 4     6   2  False
# 5     6   4  False
# 6     8   4  False
# 7    12   8  False
# 8    32  16  False
# 9    64  32   True
# 10   32  16  False
# 11   64  32   True
# 12   64  32   True
# 13   32  16  False
# 14   16   8  False
# 15   16  16  False
# 16   64  32   True
# 17    8   8  False
# 18   12   4  False
# 19   24  12  False
# 20   32  16  False
# 21   64  32   True
# 22    8   8  False
# 23    8   4  False
# 24    8   4  False
# 25   64  32   True
# 26    8   4  False
# 27   64  16  False
# 28   64  32   True
# 29   64  16  False
# 30   64  32   True
# 31   32  16  False
# 32   64  32   True
# 33   64  32   True
# 34   64  32   True
# 35   32  16  False
# 36   64  32   True
# 37   48  32   True
# 38   64  32   True
# 39   32  16  False
# 40   64  32   True
# 41   48  16  False
# 42   64  32   True
# 43   32  16  False
# 44   64  32   True
# 45   64  32   True
# 46   64  32   True
# 47   64  32   True
# 48  128  64   True
# 49  128  64   True

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median
mean_int_mem = data['Int_Mem'].mean()
median_int_mem = data['Int_Mem'].median()

# Create the histogram of the "Int_Mem" feature
plt.figure(figsize=(10,6))
plt.hist(data['Int_Mem'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of "Int_Mem" (Internal Memory)', fontsize=14)
plt.xlabel('Internal Memory (GB)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show mean and median as vertical lines on the histogram
plt.axvline(mean_int_mem, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_int_mem:.2f} GB')
plt.axvline(median_int_mem, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_int_mem:.2f} GB')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# Print the mean and median
print(f"Mean of 'Int_Mem': {mean_int_mem:.2f} GB")
print(f"Median of 'Int_Mem': {median_int_mem:.2f} GB")
# Out:
# Mean of 'Int_Mem': 173.76 GB
# Median of 'Int_Mem': 64.00 GB

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median
mean_bty_pwr = data['Bty_Pwr'].mean()
median_bty_pwr = data['Bty_Pwr'].median()

# Create the histogram of the "Bty_Pwr" feature
plt.figure(figsize=(10,6))
plt.hist(data['Bty_Pwr'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of "Bty_Pwr" (Battery Power)', fontsize=14)
plt.xlabel('Battery Power (mAh)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show mean and median as vertical lines on the histogram
plt.axvline(mean_bty_pwr, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_bty_pwr:.2f} mAh')
plt.axvline(median_bty_pwr, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_bty_pwr:.2f} mAh')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# Print the mean and median
print(f"Mean of 'Bty_Pwr': {mean_bty_pwr:.2f} mAh")
print(f"Median of 'Bty_Pwr': {median_bty_pwr:.2f} mAh")
# Out:
# Mean of 'Bty_Pwr': 3740.00 mAh
# Median of 'Bty_Pwr': 3300.00 mAh

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median

mean_ram = data['RAM'].mean()
median_ram = data['RAM'].median()

# Create the histogram of the "RAM" feature
plt.figure(figsize=(10,6))
plt.hist(data['RAM'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Histogram of "RAM" (Random Access Memory)', fontsize=14)
plt.xlabel('RAM (MB)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median


mean_depth = data['Depth'].mean()
median_depth = data['Depth'].median()

# Create the histogram of the "Depth" feature
plt.figure(figsize=(10,6))
plt.hist(data['Depth'], bins=20, color='lightblue', edgecolor='black')
plt.title('Histogram of "Depth" of Phones', fontsize=14)
plt.xlabel('Depth (mm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show mean and median as vertical lines on the histogram
plt.axvline(mean_depth, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_depth:.2f} mm')
plt.axvline(median_depth, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_depth:.2f} mm')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# Print the mean and median
print(f"Mean of 'Depth': {mean_depth:.2f} mm")
print(f"Median of 'Depth': {median_depth:.2f} mm")
# Out:
# Mean of 'Depth': 3.44 mm
# Median of 'Depth': 3.00 mm

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median
mean_weight = data['Weight'].mean()
median_weight = data['Weight'].median()

# Create the histogram of the "Weight" feature
plt.figure(figsize=(10,6))
plt.hist(data['Weight'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Histogram of "Weight" of Phones', fontsize=14)
plt.xlabel('Weight (grams)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show mean and median as vertical lines on the histogram
plt.axvline(mean_weight, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_weight:.2f} g')
plt.axvline(median_weight, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_weight:.2f} g')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# Print the mean and median
print(f"Mean of 'Weight': {mean_weight:.2f} grams")
print(f"Median of 'Weight': {median_weight:.2f} grams")
# Out:
# Mean of 'Weight': 195.20 grams
# Median of 'Weight': 190.00 grams

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"
# Calculate the median values for "Depth" and "Weight"
median_depth = data['Depth'].median()
median_weight = data['Weight'].median()

# Create the logical condition
data['con6'] = (data['Depth'] <= median_depth) & (data['Weight'] <= median_weight)

# Display the first few rows of the dataframe to verify
print(data[['Depth', 'Weight', 'con6']].head())
# Out:
#    Depth  Weight   con6
# 0      7     320  False
# 1      7     280  False
# 2      7     400  False
# 3      3     300  False
# 4      3     210  False

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (50, 21)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it
sorted_df = data.sort_values(by='Price', ascending=True)
sorted_df
# Out:
#          PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  ...  \
# 0    AAB346A  yes   yes      no      no   780   460      3      1    2  ...
# 1    AAC347I  yes   yes      no      no   780   560      2      1    4  ...
# 2    BAB657J   no   yes      no      no   840   720      2      1    4  ...
# 5    CCQ674K  yes    no      no      no  1280  1080      4      3    6  ...
# 4    CCP761U   no   yes     yes      no  1280  1080      4      3    6  ...
# 3    BBD456K   no   yes     yes      no  1280  1120      5      3    6  ...
# 18   PEL111K   no    no     yes     yes  1980  1760      8      6   12  ...
# 6    CTX123L  yes    no     yes      no  1390  1080      6      3    8  ...
# 19  PNWD777L   no    no     yes     yes  2880  2120      4      3   24  ...
# 7    DFR256N  yes    no      no      no  2880  2120      8      6   12  ...
# 22   QZR577O   no   yes     yes     yes  1440  1280      4      3    8  ...
# 24   RBZ451D   no   yes     yes     yes  1440  1280      6      4    8  ...
# 23   RAY344W   no   yes     yes     yes  2880  2120     10      8    8  ...
# 17   PDG234M   no    no     yes     yes  2880  2120      8      6    8  ...
# 21   QWR222Y   no   yes     yes     yes  2580  1980      8      6   64  ...
# 14   NBN329S  yes   yes     yes     yes  2380  1820      5      3   16  ...
# 25   SDO555G   no   yes     yes     yes  2580  1980      6      3   64  ...
# 16   PDF768G   no    no     yes     yes  2580  1980      8      6   64  ...
# 15   NSD450I   no    no     yes     yes  1980  1760     10      8   16  ...
# 9    ENG897N  yes   yes     yes     yes  2580  1980      5      3   64  ...
# 13   NAJ56GL   no   yes     yes      no  2880  2120      6      5   32  ...
# 20   POP857R   no   yes     yes     yes  1980  1760      4      3   32  ...
# 8    DGS789M  yes   yes     yes     yes  2580  1920      6      3   32  ...
# 41   WUV902Y  yes   yes     yes     yes  2580  1980      8      6   48  ...
# 12   ETT987D   no   yes     yes     yes  2580  1980      6      5   64  ...
# 30   TVF078Y  yes   yes     yes     yes  2580  2120      8      6   64  ...
# 29   SYL888P   no   yes     yes     yes  2580  2120      8      6   64  ...
# 39   VYI666I  yes   yes     yes     yes  2440  1980      6      5   32  ...
# 36   UST000T  yes   yes     yes     yes  2580  1980     10      8   64  ...
# 40   WER765T  yes   yes     yes     yes  2580  1980      5      3   64  ...
# 10   EOP657N  yes   yes     yes     yes  2580  1920      6      3   32  ...
# 28   SSD000L  yes   yes     yes     yes  2580  2120      8      6   64  ...
# 42   WZB298K  yes   yes     yes     yes  2580  1980      8      6   64  ...
# 38   VWV532Y  yes   yes     yes     yes  2580  1920      5      3   64  ...
# 26   SET568R   no   yes     yes     yes  1980  1280      5      3    8  ...
# 35   ULI999T   no   yes     yes     yes  2440  2120      5      3   32  ...
# 37   USZ111S  yes   yes     yes     yes  2440  1980      5      3   48  ...
# 11   ELS333L  yes   yes     yes     yes  2580  1920      8      6   64  ...
# 45   XXV567F   no   yes     yes     yes  2580  1980      8      6   64  ...
# 33   TYU444Q   no   yes     yes     yes  2580  2120      8      6   64  ...
# 31   TYQ109G   no   yes     yes     yes  2580  2120      8      6   32  ...
# 32   TYS938L  yes   yes     yes     yes  2580  2120      8      6   64  ...
# 27   SFK567Y  yes   yes     yes     yes  2580  2120      8      6   64  ...
# 44   XTL675G  yes   yes     yes     yes  2580  1980     10      8   64  ...
# 43   XKL901R   no   yes     yes     yes  2580  1980      8      6   32  ...
# 46   YTR67TY  yes   yes     yes     yes  2580  1980      4      3   64  ...
# 34   TYY453J  yes   yes     yes     yes  2880  2120      6      3   64  ...
# 47   ZDF789K  yes   yes     yes      no  2880  2520      8      6   64  ...
# 48   ZEO567M  yes   yes     yes      no  2880  2520      8      6  128  ...
# 49   ZZZ909X  yes   yes     yes      no  2880  2520      8      6  128  ...
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight   Price       Px      Scr_d   con4  \
# 0         8     2800    2      7     320    3297   358800   3.162278  False
# 1         8     3000    2      7     280    4500   436800   2.236068  False
# 2         8     3300    2      7     400    4898   604800   2.236068  False
# 5         8     2980    2      3     230    4990  1382400   5.000000  False
# 4        16     3000    2      3     210    5600  1382400   5.000000  False
# 3        32     3000    2      3     300    6900  1433600   5.830952  False
# 18        8     4000    4      3     330   11388  3484800  10.000000  False
# 6        32     3000    2      3     100   13400  1501200   6.708204  False
# 19       64     2800    4      3     200   14350  6105600   5.000000  False
# 7        32     3200    2      3      80   15600  6105600  10.000000  False
# 22       64     2800    8      3     170   16999  1843200   5.000000  False
# 24       32     2800    8      3     150   17890  1843200   7.211103  False
# 23       16     4800    8      3     170   18900  6105600  12.806248  False
# 17       64     2800    4      3     250   19806  6105600  10.000000  False
# 21      128     4400    4      3     160   21350  5108400  10.000000   True
# 14        8     2800    4      4      80   21972  4331600   5.830952  False
# 25       64     4500    8      3     210   22000  5108400   6.708204   True
# 16      128     3300    4      3     160   22650  5108400  10.000000   True
# 15      128     3900    6      4     180   23456  3484800  12.806248  False
# 9        64     4380    4      3     150   23456  5108400   5.830952   True
# 13       64     2800    6      4     270   23600  6105600   7.810250  False
# 20       16     2800    4      3     150   24560  3484800   5.000000  False
# 8         8     2800    6      3     120   27688  4953600   6.708204  False
# 41      128     3400    4      3     140   28000  5108400  10.000000  False
# 12       64     4500    6      4     300   28700  5108400   7.810250   True
# 30      512     4860    8      3      90   29999  5469600  10.000000   True
# 29      256     5000    8      3     320   32459  5469600  10.000000  False
# 39       32     3200    4      4     180   33460  4831200   7.810250  False
# 36       32     3000    4      4     240   34589  5108400  12.806248   True
# 40      128     3000    4      4     120   34780  5108400   5.830952   True
# 10      128     2800    4      4     210   35460  4953600   6.708204  False
# 28      512     4200    8      3     270   36555  5469600  10.000000   True
# 42     1024     5600    8      3     160   39000  5108400  10.000000   True
# 38       32     4860    8      4     310   39781  4953600   5.830952   True
# 26      128     4500    8      3     220   41320  2534400   5.830952  False
# 35       64     2800    8      4     210   42000  5172800   5.830952  False
# 37      128     4800    4      4     230   42300  4831200   5.830952   True
# 11        8     4500    8      4     150   43980  4953600  10.000000   True
# 45       64     2300    4      3     250   43990  5108400  10.000000   True
# 33      128     2800    8      3     120   45680  5469600  10.000000   True
# 31      256     3300    8      3     110   45899  5469600  10.000000  False
# 32     1024     4860    8      3     120   46777  5469600  10.000000   True
# 27       32     4300    8      3     200   49899  5469600  10.000000  False
# 44      512     4560    8      3     260   51230  5108400  12.806248   True
# 43      256     3900    4      3     210   54320  5108400  10.000000  False
# 46       64     2800    4      3     200   56000  5108400   5.000000   True
# 34      128     4400    8      4     150   61750  6105600   6.708204   True
# 47      512     5600   12      2      80   84566  7257600  10.000000   True
# 48      512     5600   12      2     110   88999  7257600  10.000000   True
# 49     1024     5600   12      2     130  149000  7257600  10.000000   True
#
#      con6
# 0   False
# 1   False
# 2   False
# 5   False
# 4   False
# 3   False
# 18  False
# 6    True
# 19  False
# 7    True
# 22   True
# 24   True
# 23   True
# 17  False
# 21   True
# 14  False
# 25  False
# 16   True
# 15  False
# 9    True
# 13  False
# 20   True
# 8    True
# 41   True
# 12  False
# 30   True
# 29  False
# 39  False
# 36  False
# 40  False
# 10  False
# 28  False
# 42   True
# 38  False
# 26  False
# 35  False
# 37  False
# 11  False
# 45  False
# 33   True
# 31   True
# 32   True
# 27  False
# 44  False
# 43  False
# 46  False
# 34  False
# 47   True
# 48   True
# 49   True
#
# [50 rows x 21 columns]

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"

std_values = data.std()
mean_values = data.mean()

# Calculate the ratio of standard deviation to mean for each feature
deviations = std_values / mean_values

# Store the ratio in a new series named 'deviations'
print(deviations)
# Out:
# Px_h       0.257998
# Px_w       0.256226
# Scr_h      0.314293
# Scr_w      0.407624
# PC         0.715716
# FC         0.712184
# Int_Mem    1.506514
# Bty_Pwr    0.256368
# RAM        0.479075
# Depth      0.306072
# Weight     0.388121
# Price      0.740868
# Px         0.398680
# Scr_d      0.340469
# con4       1.139606
# con6       1.290301
# dtype: float64
# C:\Users\sachu\AppData\Local\Temp\ipykernel_18000\4023214357.py:5: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std_values = data.std()
# C:\Users\sachu\AppData\Local\Temp\ipykernel_18000\4023214357.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = data.mean()

# %%
# View the "deviations" series after sorting it in descending order

# Sort the deviations series in descending order
deviations_sorted = deviations.sort_values(ascending=False)

# Display the sorted deviations series
print(deviations_sorted)
# Out:
# Int_Mem    1.506514
# con6       1.290301
# con4       1.139606
# Price      0.740868
# PC         0.715716
# FC         0.712184
# RAM        0.479075
# Scr_w      0.407624
# Px         0.398680
# Weight     0.388121
# Scr_d      0.340469
# Scr_h      0.314293
# Depth      0.306072
# Px_h       0.257998
# Bty_Pwr    0.256368
# Px_w       0.256226
# dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
